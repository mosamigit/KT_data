# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

df1 = pd.read_parquet('dataset_850prod_updated_m.parquet.gzip')

# %%
data = pd.read_parquet('dataset_850prod_updated_m.parquet.gzip')
filtered_data=data.iloc[856:870]

# %%
filtered_data
# Out:
#                                                   name  \
# 856                Shipment of a refrigerated products
# 857                       Solar panel shipment costing
# 858                  Featured solar panel Manufacturer
# 859                         Inxeption partner products
# 860                 Batteries in Inxeption's inventory
# 861              Solar panels in Inxeption's inventory
# 862   Monocrystalline and Polycrystalline types of ...
# 863            selection of solar panel based on usage
# 864             Cell technology for commercial purpose
# 865  Solar panel installation guide for residential...
# 866       top solar panel brands and their performance
# 867        ROI period of solar panels for residential
# 868              Installation services of solar panels
# 869   Incentives & Rebates for solar panel procurement
#
#                                                   text  n_tokens  \
# 856  Inxeption has a good experience in handling in...       224
# ...

# %%
filtered_data['text'][869]
# Out:
# "There are a number of incentives and rebates available for solar panel procurement in the United States. These incentives can vary depending on the state you live in, so it's important to do your research to find out what's available to you.\nHere are a few of the most common incentives:\nFederal tax credit: The federal government offers a 30% tax credit for the cost of installing solar panels. This credit is available for both residential and commercial solar projects.\nState and local tax credits: Many states and local governments also offer tax credits for solar panel installation. These credits can vary in size, so it's important to check with your local government to see what's available.\nRebates: Many utility companies offer rebates for solar panel installation. These rebates can be used to offset the cost of installing solar panels.\nNet metering: Net metering is a program that allows you to sell excess electricity back to your utility company. This can help you to offset th
# ...

# %%
data1 = pd.read_parquet('marketplace_url.parquet.gzip')

# %%
data1
# Out:
#                                                   name  \
# 0    Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1    Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                  Series 7 TR1- 505 - 540 Watt (530W)
# 3       RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4    Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ..                                                 ...
# 911         mSolar 440W - 144BB HC Series (35 Modules)
# 912                               Longi-355W LR4-60HPB
# 913                             Talesun - TP7G54M-400W
# 914        Imperial Star-400W ISM7-SHDD108-400/M (FFX)
# 915                   Canadian Solar 445W - CS3W-445MS
#
#                                                   text  n_tokens  \
# 0    name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1    name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2    name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
combined_df = data1.append(filtered_data, ignore_index=True)

# %%
combined_df
# Out:
#                                                   name  \
# 0    Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1    Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                  Series 7 TR1- 505 - 540 Watt (530W)
# 3       RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4    Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ..                                                 ...
# 925  Solar panel installation guide for residential...
# 926       top solar panel brands and their performance
# 927        ROI period of solar panels for residential
# 928              Installation services of solar panels
# 929   Incentives & Rebates for solar panel procurement
#
#                                                   text  n_tokens  \
# 0    name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1    name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2    name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
# Rename the columns
df = combined_data.rename(columns={'name': 'Company Name', 'text': 'Company_specification'})

# %%
df
# Out:
#                                           Company Name  \
# 0    Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1    Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                  Series 7 TR1- 505 - 540 Watt (530W)
# 3       RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4    Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ..                                                 ...
# 925  Solar panel installation guide for residential...
# 926       top solar panel brands and their performance
# 927        ROI period of solar panels for residential
# 928              Installation services of solar panels
# 929   Incentives & Rebates for solar panel procurement
#
#                                  Company_specification  n_tokens  \
# 0    name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1    name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2    name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
df.to_parquet('marketplace_combined_data.parquet.gzip', compression='gzip')

# %%
df1 = pd.read_parquet('marketplace_combined_data.parquet.gzip')

# %%
df1
# Out:
#                                           Company Name  \
# 0    Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1    Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                  Series 7 TR1- 505 - 540 Watt (530W)
# 3       RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4    Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ..                                                 ...
# 925  Solar panel installation guide for residential...
# 926       top solar panel brands and their performance
# 927        ROI period of solar panels for residential
# 928              Installation services of solar panels
# 929   Incentives & Rebates for solar panel procurement
#
#                                  Company_specification  n_tokens  \
# 0    name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1    name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2    name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
#### Combine AI_hub and clean energy

# %%
df2 = pd.read_parquet('combined_auto1.parquet.gzip')

# %%
df2
# Out:
#                                      Company Name  \
# 0                                          Google
# 1                                    Google Cloud
# 2                                           Azati
# 3                                     CrowdStrike
# 4                                            SITA
# ...                                           ...
# 1575  Wuxi Sunket New Energy Technology Co., Ltd.
# 1576             Xiamen Jumao New Energy Co., Ltd
# 1577                 Yingli Green Energy Americas
# 1578                                   UR Energy
# 1579                                  Lucid Solar
#
#                                   Company_specification  n_tokens  \
# 0     Company Division: AI Hub; Company Name: Google...       262
# 1     Company Division: AI Hub; Company Name: Google...       254
# 2     Company Division: AI Hub; Company Name: Azati;...       202
# 3     Company Division: AI Hub; Company Name: CrowdS...       160
# ...

# %%
#df2['Company_specification'][1305]
# Out:
# 'Company Division: Clean Energy;Company Name:Vestas;Company Type:Manufacturer;Vertical:Wind;Category:Wind Turbines;Company Description:With a vision to become the global leader in sustainable energy solutions, everything we do revolves around the development and deployment of sustainable energy solutions.;Email:vestas@vestas.com;Phone Number:(+45) 97 30 00 00;Website:https://www.vestas.com/en;detail address:Vestas Wind Systems A/S\nHedeager 42\n8200 Aarhus N, Denmark, Denmark '

# %%
combined_df = df1.append(df2, ignore_index=True)

# %%
combined_df.to_parquet('recomm_AI_hub_clean_energy_marketplace.parquet.gzip', compression='gzip')

# %%
combined_df
# Out:
#                                            Company Name  \
# 0     Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1     Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                   Series 7 TR1- 505 - 540 Watt (530W)
# 3        RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4     Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ...                                                 ...
# 2505        Wuxi Sunket New Energy Technology Co., Ltd.
# 2506                   Xiamen Jumao New Energy Co., Ltd
# 2507                       Yingli Green Energy Americas
# 2508                                         UR Energy
# 2509                                        Lucid Solar
#
#                                   Company_specification  n_tokens  \
# 0     name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1     name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2     name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
#p1 = pd.read_parquet('recomm_AI_hub_clean_energy_marketplace.parquet.gzip')

# %%
#p1
# Out:
#                                            Company Name  \
# 0     Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1     Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                   Series 7 TR1- 505 - 540 Watt (530W)
# 3        RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4     Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ...                                                 ...
# 2505        Wuxi Sunket New Energy Technology Co., Ltd.
# 2506                   Xiamen Jumao New Energy Co., Ltd
# 2507                       Yingli Green Energy Americas
# 2508                                         UR Energy
# 2509                                        Lucid Solar
#
#                                   Company_specification  n_tokens  \
# 0     name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1     name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2     name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
#combined_df['Company_specification'][915]
# Out:
# 'name:Canadian Solar 445W - CS3W-445MS;Manufacturer(brand):Canadian Solar;cell type:Monocrystalline;number of cells:144;wattage:445.0;height:30mm;weight:28.4;application:Commercial;product url:[Canadian Solar 445W - CS3W-445MS]("https://inxeptionmarketplace-crate.inxeption.com/purl/inxeptionenergymarketplace-canadian-solar-cs3w455mb-ag-pallet-33-modules-");image url:[\'https://s3.amazonaws.com/prisma-oce.inxeption.io/ledger207/910fee7c-39db-43cb-9e9d-1a94f2e84143/CanadianSolar_SilverFrameBifacialDualGlass_435W_460W.jpg\']'

# %%
### Combined data Ai hub,clean energy,recommender bot with packaging

# %%
df3 = pd.read_parquet('iris_package.parquet.gzip')

# %%
df3
# Out:
#                                       Company Name  \
# 0                        Pipeline Supply & Service
# 1                                Esp International
# 2                                          Flexcon
# 3                                    Yerecic Label
# 4                                        Millcraft
# ...                                            ...
# 1648                         Remcon Plastics, Inc.
# 1649                                     Robex LLC
# 1650  Robopac USA-OCME America-TopTier palletizers
# 1651                  Simplimatic, A Signode Brand
# 1652                                 Uni Pak Corp.
#
#                                   Company_specification  n_tokens  \
# 0     Company Division: Packaging;Company Name:Pipel...       107
# 1     Company Division: Packaging;Company Name:Esp I...       137
# 2     Company Division: Packaging;Company Name:Flexc...       125
# 3     Company Division: Packaging;Company Name:Yerec...       139
# ...

# %%
df4 = combined_df.append(df3, ignore_index=True)

# %%
df4
# Out:
#                                            Company Name  \
# 0     Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1     Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                   Series 7 TR1- 505 - 540 Watt (530W)
# 3        RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4     Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ...                                                 ...
# 4158                              Remcon Plastics, Inc.
# 4159                                          Robex LLC
# 4160       Robopac USA-OCME America-TopTier palletizers
# 4161                       Simplimatic, A Signode Brand
# 4162                                      Uni Pak Corp.
#
#                                   Company_specification  n_tokens  \
# 0     name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1     name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2     name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
df4.to_parquet('marketplace_package.parquet.gzip', compression='gzip')

# %%
#p2 = pd.read_parquet('marketplace_package.parquet.gzip')

# %%
#p2
# Out:
#                                            Company Name  \
# 0     Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1     Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                   Series 7 TR1- 505 - 540 Watt (530W)
# 3        RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4     Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ...                                                 ...
# 4158                              Remcon Plastics, Inc.
# 4159                                          Robex LLC
# 4160       Robopac USA-OCME America-TopTier palletizers
# 4161                       Simplimatic, A Signode Brand
# 4162                                      Uni Pak Corp.
#
#                                   Company_specification  n_tokens  \
# 0     name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1     name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2     name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
#p2['Company_specification'][4160]
# Out:
# 'Company Division: Packaging;Company Name:Robopac USA-OCME America-TopTier palletizers;Company Type:Distribution & Supply Chain;Vertical:Glass, Paper, Metal, Plastic;Category:Packaging Product Distributors, Packaging Equipment Distributors, Pick & Pack Services, Pallets & Containers, Palletizing Equipment & Accessories, Pallet Conveyors, Depalletizing Equipment;Company Description:Robopac is a leading manufacturer of end of line packaging solutions including stretch wrapper, case packers, and palletizers. With over 250 semi-automatic stretch wrappers in stock, we are able to quickly deliver the right solution to meet your needs. OCME provides packaging solutions including filling, packing, palletizing, depalletizing, stretch wrapping, banding, and internal logistics.;Email:info.us@robopac.com;Website:https://www.robopacusa.com/;detail address:10315 SE Jennifer Street, Clackamas, Oregon , USA, 97015'

# %%
### Combined data Ai hub,clean energy,recommender bot,packaging with additional data

# %%
df5 = pd.read_parquet('Add_data.parquet.gzip')

# %%
df5
# Out:
#                      Company Name  \
# 0                       Inxeption
# 1                        Ask iris
# 2  Opt-out of Marketing Campaigns
# 3                              AI
#
#                                Company_specification  n_tokens  \
# 0  Company Name:Inxeption;Company Description:Inx...       119
# 1  Ask iris:Ask iris is an artificial intelligenc...        32
# 2  Opt-Out:Inxeption uses online advertising serv...       139
# 3  AI:AI, or Artificial Intelligence, refers to t...        74
#
#                                           embeddings
# 0  [0.0031530484557151794, -0.009379514493048191,...
# 1  [-0.012790778651833534, -0.0019283423898741603...
# 2  [-0.013076036237180233, 0.001688232528977096, ...
# 3  [-0.017367329448461533, -0.02865929715335369, ...

# %%
#df5['Company_specification'][2]
# Out:
# 'Opt-Out:Inxeption uses online advertising services that employ cookies and similar technologies to collect information about your device and online activity on our sites, apps, and other online services. The advertising services use this information to try to tailor the ads you see online to your interests. These ads are called interest-based ads. The privacy laws in certain states, including California, Virginia and Colorado,  may classify our use of these services as a “sale” of personal information to those advertising services from which residents of such states have the right to opt-out.\nFor more details and instructions on how to opt-out, please visit our data privacy page("https://www.inxeption.com/data-privacy").'

# %%
complete = df4.append(df5, ignore_index=True)

# %%
complete
# Out:
#                                            Company Name  \
# 0     Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1     Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                   Series 7 TR1- 505 - 540 Watt (530W)
# 3        RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4     Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ...                                                 ...
# 4162                                      Uni Pak Corp.
# 4163                                          Inxeption
# 4164                                           Ask iris
# 4165                     Opt-out of Marketing Campaigns
# 4166                                                 AI
#
#                                   Company_specification  n_tokens  \
# 0     name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1     name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2     name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
complete.to_parquet('new_askiris_ora.parquet.gzip', compression='gzip')

# %%
#p3 = pd.read_parquet('new_askiris_ora.parquet.gzip')

# %%
#p3
# Out:
#                                            Company Name  \
# 0     Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1     Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                   Series 7 TR1- 505 - 540 Watt (530W)
# 3        RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4     Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ...                                                 ...
# 4162                                      Uni Pak Corp.
# 4163                                          Inxeption
# 4164                                           Ask iris
# 4165                     Opt-out of Marketing Campaigns
# 4166                                                 AI
#
#                                   Company_specification  n_tokens  \
# 0     name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1     name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2     name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
p3['Company_specification'][0]
# Out:
# 'name:Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. All Black. (365W);Manufacturer(brand):Jinko Solar;cell type:N-type Monocrystalline;number of cells:120;wattage:365.0;height:30mm;weight:8.62;application:Residential;product url:[Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. All Black. (365W)]("https://inxeptionmarketplace-crate.inxeption.com/purl/inxeptionenergymarketplace-tiger-n-type-60tr-355-375-watt-mono-facial-all-black-365w-");image url:[\'https://s3.amazonaws.com/prisma-oce.inxeption.io/ledger207/4d8dfb27-0e8f-4180-b383-fe26dedfc7e4/Tiger%20N-Type%2060TR.%20355-375%20Watt.%20Mono-Facial.%20All%20Black.%20%28365W%29_img.jpg\']'
