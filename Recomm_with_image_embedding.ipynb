# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("products_with_image.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0  Tiger Pro 72HC-BDVP. 530-550 Watt. Bifacial Mo...
# 1           1    RSM40-8-390M-415M - 390 - 415 Watt (390W) Steel
# 2           2  Mono 470W MBB Half-Cell Module - 445 - 470 Wat...
# 3           3  BiHiKu. 435 - 460 Watt. High Power Bifacial Mo...
# 4           4  LG NeON R 60 cell Monocrystalline 365W - 385 W...
#
#                                                 text
# 0  name:Tiger Pro 72HC-BDVP. 530-550 Watt. Bifaci...
# 1  name:RSM40-8-390M-415M - 390 - 415 Watt (390W)...
# 2  name:Mono 470W MBB Half-Cell Module - 445 - 47...
# 3  name:BiHiKu. 435 - 460 Watt. High Power Bifaci...
# 4  name:LG NeON R 60 cell Monocrystalline 365W - ...

# %% [markdown]
# Data cleaning
# 1.Remove HTML tags from description column

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'name', 'text'], dtype='object')

# %%
data = data.drop(['Unnamed: 0'],axis=1)

# %%
data.shape
# Out:
# (856, 2)

# %%
data
# Out:
#                                                   name  \
# 0    Tiger Pro 72HC-BDVP. 530-550 Watt. Bifacial Mo...
# 1      RSM40-8-390M-415M - 390 - 415 Watt (390W) Steel
# 2    Mono 470W MBB Half-Cell Module - 445 - 470 Wat...
# 3    BiHiKu. 435 - 460 Watt. High Power Bifacial Mo...
# 4    LG NeON R 60 cell Monocrystalline 365W - 385 W...
# ..                                                 ...
# 851  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 852  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 853                     Meyer Burger-385HJT-Black-Blem
# 854                            Bluesun-BSM415M10-54HPH
# 855              Boviet Solar-BVM6612M-440S-H-HC-BF-DG
#
#                                                   text
# 0    name:Tiger Pro 72HC-BDVP. 530-550 Watt. Bifaci...
# 1    name:RSM40-8-390M-415M - 390 - 415 Watt (390W)...
# 2    name:Mono 470W MBB Half-Cell Module - 445 - 47...
# 3    name:BiHiKu. 435 - 460 Watt. High Power Bifaci...
# ...

# %%
# imports
#import plotly
import openai
import pandas as pd
import tiktoken
import sklearn

from openai.embeddings_utils import get_embedding

# %%
#data = pd.read_csv('embedding_data_5_31_less_feature.csv',index_col=0)

# %%
# embedding model parameters
embedding_model = "text-embedding-ada-002"
embedding_encoding = "cl100k_base"  # this the encoding for text-embedding-ada-002
max_tokens = 8000  # the maximum for text-embedding-ada-002 is 8191

# %%
#openai.api_key = 'sk-f00iZE7fpcUMQqsNBAH5T3BlbkFJxNTyQmhSW'###kcs
openai.api_key = 'sk-kZAcnb4xH3LbPHI4n2sWT3BlbkFJvuC8rNr'###Inx

# %%
data
# Out:
#                                                   name  \
# 0    Tiger Pro 72HC-BDVP. 530-550 Watt. Bifacial Mo...
# 1      RSM40-8-390M-415M - 390 - 415 Watt (390W) Steel
# 2    Mono 470W MBB Half-Cell Module - 445 - 470 Wat...
# 3    BiHiKu. 435 - 460 Watt. High Power Bifacial Mo...
# 4    LG NeON R 60 cell Monocrystalline 365W - 385 W...
# ..                                                 ...
# 851  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 852  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 853                     Meyer Burger-385HJT-Black-Blem
# 854                            Bluesun-BSM415M10-54HPH
# 855              Boviet Solar-BVM6612M-440S-H-HC-BF-DG
#
#                                                   text
# 0    name:Tiger Pro 72HC-BDVP. 530-550 Watt. Bifaci...
# 1    name:RSM40-8-390M-415M - 390 - 415 Watt (390W)...
# 2    name:Mono 470W MBB Half-Cell Module - 445 - 47...
# 3    name:BiHiKu. 435 - 460 Watt. High Power Bifaci...
# ...

# %%
import tiktoken

# Load the cl100k_base tokenizer which is designed to work with the ada-002 model
tokenizer = tiktoken.get_encoding("cl100k_base")
#p50k_base
#cl100k_base
#df = pd.read_csv('processed/scraped.csv', index_col=0)
#df = pd.read_excel('embedding_5.xlsx',index_col=0)
#data.columns = ['fname', 'combined']

# Tokenize the text and save the number of tokens to a new column
data['n_tokens'] = data.text.apply(lambda x: len(tokenizer.encode(x)))

# %%
data
# Out:
#                                                   name  \
# 0    Tiger Pro 72HC-BDVP. 530-550 Watt. Bifacial Mo...
# 1      RSM40-8-390M-415M - 390 - 415 Watt (390W) Steel
# 2    Mono 470W MBB Half-Cell Module - 445 - 470 Wat...
# 3    BiHiKu. 435 - 460 Watt. High Power Bifacial Mo...
# 4    LG NeON R 60 cell Monocrystalline 365W - 385 W...
# ..                                                 ...
# 851  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 852  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 853                     Meyer Burger-385HJT-Black-Blem
# 854                            Bluesun-BSM415M10-54HPH
# 855              Boviet Solar-BVM6612M-440S-H-HC-BF-DG
#
#                                                   text  n_tokens
# 0    name:Tiger Pro 72HC-BDVP. 530-550 Watt. Bifaci...       249
# 1    name:RSM40-8-390M-415M - 390 - 415 Watt (390W)...       229
# 2    name:Mono 470W MBB Half-Cell Module - 445 - 47...       226
# ...

# %%
data["embeddings"] = data.text.apply(lambda x: get_embedding(x, engine=embedding_model))
#data.to_csv("embedding_19_05_05_33_lessfeature.csv")

# %%
for i in data['embeddings'][0]:
    print(i,end="---")
# Out:
# 0.004894706420600414---0.005102421622723341----0.010379056446254253---0.00973580963909626----0.02057049795985222---0.01504929643124342----0.022634249180555344----0.00932707916945219----0.007792667485773563----0.04159662872552872---0.013246865011751652---0.02055709809064865----0.02741839736700058----0.009588398039340973---0.009293576702475548---0.01332056988030672----0.004137551411986351---0.008918349631130695----0.0020570498891174793---0.004228007979691029----0.014499856159090996---0.021079735830426216----0.018466545268893242----0.00485785398632288----0.009233272634446621----0.004197855945676565---0.027163779363036156----0.0014221785822883248----0.02538144960999489----0.004787498619407415----0.0002987998886965215----0.006626782938838005----0.022098209708929062----0.007839570753276348---0.026574134826660156---0.01232889760285616---0.011578443460166454---0.008596725761890411---0.03768354654312134---0.013400976546108723---0.036155834794044495----0.015437924303114414---0.0073638362810015
# ...

# %%
data['embeddings'][0]
# Out:
# [0.004894706420600414,
#  0.005102421622723341,
#  -0.010379056446254253,
#  0.00973580963909626,
#  -0.02057049795985222,
#  0.01504929643124342,
#  -0.022634249180555344,
#  -0.00932707916945219,
#  -0.007792667485773563,
#  -0.04159662872552872,
#  0.013246865011751652,
#  0.02055709809064865,
#  -0.02741839736700058,
#  -0.009588398039340973,
#  0.009293576702475548,
#  0.01332056988030672,
#  -0.004137551411986351,
#  0.008918349631130695,
#  -0.0020570498891174793,
#  0.004228007979691029,
#  -0.014499856159090996,
#  0.021079735830426216,
#  -0.018466545268893242,
#  -0.00485785398632288,
#  -0.009233272634446621,
#  -0.004197855945676565,
#  0.027163779363036156,
#  -0.0014221785822883248,
#  -0.02538144960999489,
#  -0.004787498619407415,
#  -0.0002987998886965215,
#  -0.006626782938838005,
#  -0.022098209708929062,
#  -0.007839570753276348,
#  0.026574134826660156,
#  0.01232889760285616,
#  0.011578443460166454,
#  0.008596725761890411,
#  0.03768354654312134,
# ...

# %%
#data.to_excel("new_try.xlsx")

# %%
#data.to_excel("try1.xlsx")

# %%
#size = 'babbage'


#from openai.embeddings_utils import get_embedding

#data['embeddings'] = data.text.apply(lambda x: get_embedding(x, engine=f'text-search-{size}-doc-001'))
#data.to_csv('processed/embeddings_morning_22_05.csv')
#data.head()
# Out:
#                                                 name  \
# 0  Tiger Pro 72HCBDVP 530550 Watt Bifacial Module...
# 1           RSM408390M415M  390  415 Watt 390W Steel
# 2  Mono 470W MBB HalfCell Module  445  470 Watt 470W
# 3  BiHiKu 435  460 Watt High Power Bifacial Monoc...
# 4  LG NeON R 60 cell Monocrystalline 365W  385 Wa...
#
#                                                 text  n_tokens  \
# 0  name: Tiger Pro 72HCBDVP 530550 Watt Bifacial ...       160
# 1  name: RSM408390M415M  390  415 Watt 390W Steel...       147
# 2  name: Mono 470W MBB HalfCell Module  445  470 ...       142
# 3  name: BiHiKu 435  460 Watt High Power Bifacial...       163
# 4  name: LG NeON R 60 cell Monocrystalline 365W  ...       150
#
#                                           embeddings
# 0  [-0.010732404887676239, 0.011029381304979324, ...
# 1  [-0.03654223307967186, 0.038443274796009064, 0...
# 2  [-0.018389349803328514, 0.027152061462402344, ...
# ...

# %%
#data = pd.read_csv("processed/embeddings_morning_22_05.csv")

# %%
#import numpy as np

# %%
data
# Out:
#                                                   name  \
# 0    Tiger Pro 72HC-BDVP. 530-550 Watt. Bifacial Mo...
# 1      RSM40-8-390M-415M - 390 - 415 Watt (390W) Steel
# 2    Mono 470W MBB Half-Cell Module - 445 - 470 Wat...
# 3    BiHiKu. 435 - 460 Watt. High Power Bifacial Mo...
# 4    LG NeON R 60 cell Monocrystalline 365W - 385 W...
# ..                                                 ...
# 851  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 852  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 853                     Meyer Burger-385HJT-Black-Blem
# 854                            Bluesun-BSM415M10-54HPH
# 855              Boviet Solar-BVM6612M-440S-H-HC-BF-DG
#
#                                                   text  n_tokens  \
# 0    name:Tiger Pro 72HC-BDVP. 530-550 Watt. Bifaci...       249
# 1    name:RSM40-8-390M-415M - 390 - 415 Watt (390W)...       229
# 2    name:Mono 470W MBB Half-Cell Module - 445 - 47...       226
# ...

# %%
# data.to_parquet('recomm_with_image.parquet.gzip',compression='gzip')

# %%
df = pd.read_parquet('recomm_with_image.parquet.gzip')

# %%
df
# Out:
#                                                   name  \
# 0    Tiger Pro 72HC-BDVP. 530-550 Watt. Bifacial Mo...
# 1      RSM40-8-390M-415M - 390 - 415 Watt (390W) Steel
# 2    Mono 470W MBB Half-Cell Module - 445 - 470 Wat...
# 3    BiHiKu. 435 - 460 Watt. High Power Bifacial Mo...
# 4    LG NeON R 60 cell Monocrystalline 365W - 385 W...
# ..                                                 ...
# 851  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 852  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 853                     Meyer Burger-385HJT-Black-Blem
# 854                            Bluesun-BSM415M10-54HPH
# 855              Boviet Solar-BVM6612M-440S-H-HC-BF-DG
#
#                                                   text  n_tokens  \
# 0    name:Tiger Pro 72HC-BDVP. 530-550 Watt. Bifaci...       249
# 1    name:RSM40-8-390M-415M - 390 - 415 Watt (390W)...       229
# 2    name:Mono 470W MBB Half-Cell Module - 445 - 47...       226
# ...

# %%
# Rename the columns
df = df.rename(columns={'name': 'Company Name', 'text': 'Company_specification'})

# %%
df
# Out:
#                                           Company Name  \
# 0    Tiger Pro 72HC-BDVP. 530-550 Watt. Bifacial Mo...
# 1      RSM40-8-390M-415M - 390 - 415 Watt (390W) Steel
# 2    Mono 470W MBB Half-Cell Module - 445 - 470 Wat...
# 3    BiHiKu. 435 - 460 Watt. High Power Bifacial Mo...
# 4    LG NeON R 60 cell Monocrystalline 365W - 385 W...
# ..                                                 ...
# 851  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 852  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 853                     Meyer Burger-385HJT-Black-Blem
# 854                            Bluesun-BSM415M10-54HPH
# 855              Boviet Solar-BVM6612M-440S-H-HC-BF-DG
#
#                                  Company_specification  n_tokens  \
# 0    name:Tiger Pro 72HC-BDVP. 530-550 Watt. Bifaci...       249
# 1    name:RSM40-8-390M-415M - 390 - 415 Watt (390W)...       229
# 2    name:Mono 470W MBB Half-Cell Module - 445 - 47...       226
# ...

# %%
df.to_parquet('recomm_with_image.parquet.gzip',compression='gzip')

# %%
#df1 = pd.read_parquet('recomm_with_image.parquet.gzip')

# %%
#df1
# Out:
#                                           Company Name  \
# 0    Tiger Pro 72HC-BDVP. 530-550 Watt. Bifacial Mo...
# 1      RSM40-8-390M-415M - 390 - 415 Watt (390W) Steel
# 2    Mono 470W MBB Half-Cell Module - 445 - 470 Wat...
# 3    BiHiKu. 435 - 460 Watt. High Power Bifacial Mo...
# 4    LG NeON R 60 cell Monocrystalline 365W - 385 W...
# ..                                                 ...
# 851  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 852  Monocrystalline MAXEON PERFORMANCE 5 - 495 - 5...
# 853                     Meyer Burger-385HJT-Black-Blem
# 854                            Bluesun-BSM415M10-54HPH
# 855              Boviet Solar-BVM6612M-440S-H-HC-BF-DG
#
#                                  Company_specification  n_tokens  \
# 0    name:Tiger Pro 72HC-BDVP. 530-550 Watt. Bifaci...       249
# 1    name:RSM40-8-390M-415M - 390 - 415 Watt (390W)...       229
# 2    name:Mono 470W MBB Half-Cell Module - 445 - 47...       226
# ...
