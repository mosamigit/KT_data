# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("marketplace_data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0  Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1           1  Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2           2                Series 7 TR1- 505 - 540 Watt (530W)
# 3           3     RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4           4  Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
#
#                                                 text
# 0  name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...
# 1  name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...
# 2  name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...
# 3  name:RSM40-8-385MB-405MB - 385 - 405 Watt (395...
# 4  name:Eagle 66TR G4. 380-400 Watt. Tiling Ribbo...

# %%
#### Data cleaning 1.Remove HTML tags from description column

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'name', 'text'], dtype='object')

# %%
data = data.drop(['Unnamed: 0'],axis=1)

# %%
data.shape
# Out:
# (916, 2)

# %%
data
# Out:
#                                                   name  \
# 0    Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1    Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                  Series 7 TR1- 505 - 540 Watt (530W)
# 3       RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4    Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ..                                                 ...
# 911         mSolar 440W - 144BB HC Series (35 Modules)
# 912                               Longi-355W LR4-60HPB
# 913                             Talesun - TP7G54M-400W
# 914        Imperial Star-400W ISM7-SHDD108-400/M (FFX)
# 915                   Canadian Solar 445W - CS3W-445MS
#
#                                                   text
# 0    name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...
# 1    name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...
# 2    name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...
# 3    name:RSM40-8-385MB-405MB - 385 - 405 Watt (395...
# ...

# %%
# imports
#import plotly
import openai
import pandas as pd
import tiktoken
import sklearn

from openai.embeddings_utils import get_embedding

# %%
# embedding model parameters
embedding_model = "text-embedding-ada-002"
embedding_encoding = "cl100k_base"  # this the encoding for text-embedding-ada-002
max_tokens = 8000  # the maximum for text-embedding-ada-002 is 8191

# %%
#openai.api_key = 'sk-f00iZE7fpcUMQqsNBAH5T3BlbkFJxN'###kcs
openai.api_key = 'sk-kZAcnb4xH3LbPHI4n2sWT3BlbkFJvu'###Inx

# %%
data
# Out:
#                                                   name  \
# 0    Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1    Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                  Series 7 TR1- 505 - 540 Watt (530W)
# 3       RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4    Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ..                                                 ...
# 911         mSolar 440W - 144BB HC Series (35 Modules)
# 912                               Longi-355W LR4-60HPB
# 913                             Talesun - TP7G54M-400W
# 914        Imperial Star-400W ISM7-SHDD108-400/M (FFX)
# 915                   Canadian Solar 445W - CS3W-445MS
#
#                                                   text
# 0    name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...
# 1    name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...
# 2    name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...
# 3    name:RSM40-8-385MB-405MB - 385 - 405 Watt (395...
# ...

# %%
import tiktoken

# Load the cl100k_base tokenizer which is designed to work with the ada-002 model
tokenizer = tiktoken.get_encoding("cl100k_base")
#p50k_base
#cl100k_base
#df = pd.read_csv('processed/scraped.csv', index_col=0)
#df = pd.read_excel('embedding_5.xlsx',index_col=0)
#data.columns = ['fname', 'combined']

# Tokenize the text and save the number of tokens to a new column
data['n_tokens'] = data.text.apply(lambda x: len(tokenizer.encode(x)))

# %%
data
# Out:
#                                                   name  \
# 0    Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1    Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                  Series 7 TR1- 505 - 540 Watt (530W)
# 3       RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4    Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ..                                                 ...
# 911         mSolar 440W - 144BB HC Series (35 Modules)
# 912                               Longi-355W LR4-60HPB
# 913                             Talesun - TP7G54M-400W
# 914        Imperial Star-400W ISM7-SHDD108-400/M (FFX)
# 915                   Canadian Solar 445W - CS3W-445MS
#
#                                                   text  n_tokens
# 0    name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1    name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2    name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
data["embeddings"] = data.text.apply(lambda x: get_embedding(x, engine=embedding_model))

# %%
for i in data['embeddings'][0]:
    print(i,end="---")
# Out:
# 0.010203628800809383---0.0030644561629742384----0.0058359368704259396---0.01220394391566515----0.010466296225786209----0.005980740766972303----0.017389945685863495----0.023384157568216324----0.005957168061286211----0.03345981985330582---0.027856241911649704---0.01823856495320797----0.03073885105550289----0.0034887653309851885---0.004414837341755629---0.011395735666155815---0.010244038887321949---0.001153380493633449---0.004435042385011911----0.008971110917627811----0.007193053141236305---0.028637509793043137----0.04119167849421501----0.004243093077093363----0.0013242828426882625---0.007880030199885368---0.003052669810131192----0.005758483428508043----0.022656770423054695----0.00818310771137476---0.0014034198829904199----0.005084976553916931----0.022454718127846718----0.02619941532611847---0.008021466434001923---0.013012152165174484---0.015962112694978714----0.006991000846028328---0.027330907061696053---0.012042301706969738---0.025350797921419144----0.002562693553045392---0.0027697968
# ...

# %%
data['embeddings'][0]
# Out:
# [0.010203628800809383,
#  0.0030644561629742384,
#  -0.0058359368704259396,
#  0.01220394391566515,
#  -0.010466296225786209,
#  -0.005980740766972303,
#  -0.017389945685863495,
#  -0.023384157568216324,
#  -0.005957168061286211,
#  -0.03345981985330582,
#  0.027856241911649704,
#  0.01823856495320797,
#  -0.03073885105550289,
#  -0.0034887653309851885,
#  0.004414837341755629,
#  0.011395735666155815,
#  0.010244038887321949,
#  0.001153380493633449,
#  0.004435042385011911,
#  -0.008971110917627811,
#  -0.007193053141236305,
#  0.028637509793043137,
#  -0.04119167849421501,
#  -0.004243093077093363,
#  -0.0013242828426882625,
#  0.007880030199885368,
#  0.003052669810131192,
#  -0.005758483428508043,
#  -0.022656770423054695,
#  -0.00818310771137476,
#  0.0014034198829904199,
#  -0.005084976553916931,
#  -0.022454718127846718,
#  -0.02619941532611847,
#  0.008021466434001923,
#  0.013012152165174484,
#  0.015962112694978714,
#  -0.006991000846028328,
#  0.027330907061696053,
# ...

# %%
data
# Out:
#                                                   name  \
# 0    Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1    Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                  Series 7 TR1- 505 - 540 Watt (530W)
# 3       RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4    Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ..                                                 ...
# 911         mSolar 440W - 144BB HC Series (35 Modules)
# 912                               Longi-355W LR4-60HPB
# 913                             Talesun - TP7G54M-400W
# 914        Imperial Star-400W ISM7-SHDD108-400/M (FFX)
# 915                   Canadian Solar 445W - CS3W-445MS
#
#                                                   text  n_tokens  \
# 0    name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1    name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2    name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
#data.to_parquet('marketplace_url.parquet.gzip',compression='gzip')

# %%
df = pd.read_parquet('marketplace_url.parquet.gzip')

# %%
df
# Out:
#                                                   name  \
# 0    Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. ...
# 1    Eagle 78TR G4b. 445-465 Watt. Tiling Ribbon Bi...
# 2                  Series 7 TR1- 505 - 540 Watt (530W)
# 3       RSM40-8-385MB-405MB - 385 - 405 Watt (395W) MB
# 4    Eagle 66TR G4. 380-400 Watt. Tiling Ribbon Mod...
# ..                                                 ...
# 911         mSolar 440W - 144BB HC Series (35 Modules)
# 912                               Longi-355W LR4-60HPB
# 913                             Talesun - TP7G54M-400W
# 914        Imperial Star-400W ISM7-SHDD108-400/M (FFX)
# 915                   Canadian Solar 445W - CS3W-445MS
#
#                                                   text  n_tokens  \
# 0    name:Tiger N-Type 60TR. 355-375 Watt. Mono-Fac...       235
# 1    name:Eagle 78TR G4b. 445-465 Watt. Tiling Ribb...       250
# 2    name:Series 7 TR1- 505 - 540 Watt (530W);Manuf...       196
# ...

# %%
#df['text'][0]
# Out:
# 'name:Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. All Black. (365W);Manufacturer(brand):Jinko Solar;cell type:N-type Monocrystalline;number of cells:120;wattage:365.0;height:30mm;weight:8.62;application:Residential;product url:[Tiger N-Type 60TR. 355-375 Watt. Mono-Facial. All Black. (365W)]("https://inxeptionmarketplace-crate.inxeption.com/purl/inxeptionenergymarketplace-tiger-n-type-60tr-355-375-watt-mono-facial-all-black-365w-");image url:[\'https://s3.amazonaws.com/prisma-oce.inxeption.io/ledger207/4d8dfb27-0e8f-4180-b383-fe26dedfc7e4/Tiger%20N-Type%2060TR.%20355-375%20Watt.%20Mono-Facial.%20All%20Black.%20%28365W%29_img.jpg\']'
